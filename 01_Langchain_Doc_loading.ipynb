# %%
#!pip install langchain_openai langchain_core python-dotenv streamlit langchain_community langserve fastapi uvicorn sse_starlette bs4 pypdf chromadb faiss-cpu groq cassio beautifulsoup4 langchain-groq Wikipedia arxiv langchainhub sentence_transformers PyPDF2 langchain-objectbox

# %% [markdown]
# # PDF loader

# %%
from langchain_community.llms import Ollama

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("National AI Policy Consultation Draft V1.pdf")
pages = loader.load()

# %%
#Check the length of pages
len(pages)
# Out:
# 41

# %%
page = pages[0]

# %%
page
# Out:
# Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2023-05-02T10:52:11+05:00', 'title': 'Feasibility Study of National Centers of Research Innovation and Entrepreneurship in Artificial intelligence and Allied Technologies      (NCRIE-AI)', 'author': 'Zeeshan Bokhari', 'moddate': '2023-05-15T12:55:07+05:00', 'source': 'National AI Policy Consultation Draft V1.pdf', 'total_pages': 41, 'page': 0, 'page_label': '1'}, page_content='i\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n                        Draft\nNational\n \nArtificial Intelligence Policy\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nGovernment of Pakistan\nMinistry of Information Technology & Telecommunication\nhttps://moitt.gov.pk')

# %%
#Check the source of data
page.metadata["source"]
# Out:
# 'National AI Policy Consultation Draft V1.pdf'

# %%
#Print the metadata page number
#hint use metadata and page
page.metadata
# Out:
# {'producer': 'Microsoft® Word 2019',
#  'creator': 'Microsoft® Word 2019',
#  'creationdate': '2023-05-02T10:52:11+05:00',
#  'title': 'Feasibility Study of National Centers of Research Innovation and Entrepreneurship in Artificial intelligence and Allied Technologies      (NCRIE-AI)',
#  'author': 'Zeeshan Bokhari',
#  'moddate': '2023-05-15T12:55:07+05:00',
#  'source': 'National AI Policy Consultation Draft V1.pdf',
#  'total_pages': 41,
#  'page': 0,
#  'page_label': '1'}

# %% [markdown]
# # Text Loader

# %%
#Use the text file
from langchain_community.document_loaders import TextLoader
text = TextLoader("sample1.txt")
data = text.load()

# %%
len(data)
# Out:
# 1

# %%
data
# Out:
# [Document(metadata={'source': 'sample1.txt'}, page_content='Utilitatis causa amicitia est quaesita.\nLorem ipsum dolor sit amet, consectetur adipiscing elit. Collatio igitur ista te nihil iuvat. Honesta oratio, Socratica, Platonis etiam. Primum in nostrane potestate est, quid meminerimus? Duo Reges: constructio interrete. Quid, si etiam iucunda memoria est praeteritorum malorum? Si quidem, inquit, tollerem, sed relinquo. An nisi populari fama?\n\nQuamquam id quidem licebit iis existimare, qui legerint. Summum a vobis bonum voluptas dicitur. At hoc in eo M. Refert tamen, quo modo. Quid sequatur, quid repugnet, vident. Iam id ipsum absurdum, maximum malum neglegi.')]

# %% [markdown]
# # Document loader

# %%
#!pip install docx2txt

# %%
from langchain_community.document_loaders import Docx2txtLoader
docs = Docx2txtLoader("Things I Never Said To Myse.docx")
doc_data =docs.load()

# %%
doc_data
# Out:
# [Document(metadata={'source': 'Things I Never Said To Myse.docx'}, page_content="Dear Self,\n\nDear Self,\n\nDear Self,\n\nDear Self,\n\nDear Self,\n\nDear Self,\n\nDear Self,\n\nDear Self,\n\nDear Self,\n\n\n\n\n\n\n\n\n\nTHINGS I NEVER SAID TO\n\nMYSELF\n\nDuduzile Noeleen Ngwenya\n\nDedication\n\nTo my family,\n\nThank you for always pushing me to be my best self and allowing me to live. If I had to be reborn, I'd choose you to be my family, over and over again.\n\nOceanofPDF.com\n\n\n\nDear Self,\n\nThis is a book filled with words I failed to say to you when you needed me to.\n\n\n\n\nTABLE OF CONTENTS\n\nAuthor’s Letter …………………………………. 3\n\nCollection i …………………………………….... 5 \n\nCollection ii …...…………………………….…. 61\n\nCollection iii …...…………………………...… 112\n\nFinal Thoughts ….…………………………….127\n\n\n\nAUTHOR’S LETTER\n\nIt's been about three years since I started writing this book. Well, for starters, I'll put it out there that one of the reasons for that is that I felt like it isn't 
# ...

# %%
doc_data[0].metadata
#Meta data is used for info varifaction
# Out:
# {'source': 'Things I Never Said To Myse.docx'}

# %% [markdown]
# # URLs

# %%
from langchain.document_loaders import WebBaseLoader
import bs4
urls =WebBaseLoader("https://ai.google/")
url_data =urls.load()

# %%
url_data
# Out:
# [Document(metadata={'source': 'https://ai.google/', 'title': '\n      \n        Making AI helpful for everyone - Google AI\n      \n      \n        \n        - Google AI\n      \n    ', 'description': 'Committed to improving the lives of as many people as possible, responsibly building products and platforms powered by the most advanced technology.', 'language': 'en'}, page_content="\n\n\n\n\n\n      \n        Making AI helpful for everyone - Google AI\n      \n      \n        \n        - Google AI\n      \n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n 
# ...

# %%
urs = WebBaseLoader("https://www.punjabpolice.gov.pk/")
df= urs.load()

# %%
df
# Out:
# [Document(metadata={'source': 'https://www.punjabpolice.gov.pk/', 'title': 'Punjab Police', 'language': 'en'}, page_content='\n\n\n\n\n\n\n\n\nPunjab Police\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to main content\n\n\n\n\n\n\n\n\n\nToggle navigation\n\n\n\n\n\n\n\nAbout Us\nPublic Services\nPolice Initiatives\nStatistics\nMedia Room\nIGP Complaint Center\nWelfare MoUs\nOnline License\nRTI\n \n\n\nSearch form\nSearch\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFacebook\nTwitter\nInstagram\nMobile Apps\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n \n\n\n\n \n\n \n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\nPublic Services\n\n\n\nFrequentlyAskedQuestions\nFrequentlyAsked Questions\n\n\n\n\nKhidmatMarkaz\nKhidmatMarkaz\n\n\n\n\nSafetyTips\nSafetyTips\n\n\n\n\nWomenHelp\nWomenHelp\n\n\n\nView All\n \n\n\xa0 \xa0 \xa0\xa0 \xa0 \xa0\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nReport\nReport\nv\n\n\n\n\nMissing Persons\nMissing Children\nLoss\nCrime
# ...
